# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
tm = pd.read_csv('TLKM1.JK.CSV', parse_dates = ['Date'],index_col='Date')
isat = pd.read_csv('ISAT.JK.CSV', parse_dates = ['Date'],index_col='Date')
fr = pd.read_csv('fren.JK.CSV', parse_dates = ['Date'],index_col='Date')
xl = pd.read_csv('excl.JK.CSV', parse_dates = ['Date'],index_col='Date')

# %%
tm
# Out:
#               Open    High     Low   Close    Adj Close     Volume
# Date
# 2019-03-18  3770.0  3820.0  3760.0  3820.0  3716.218506   44322600
# 2019-03-19  3800.0  3820.0  3770.0  3780.0  3677.305176   33156500
# 2019-03-20  3810.0  3820.0  3750.0  3760.0  3657.848633   42784600
# 2019-03-21  3800.0  3810.0  3780.0  3790.0  3687.033691   36527500
# 2019-03-22  3800.0  3820.0  3790.0  3800.0  3696.761963   26772900
# ...            ...     ...     ...     ...          ...        ...
# 2019-06-10  4000.0  4060.0  3970.0  4040.0  3930.241699  222522800
# 2019-06-11  4010.0  4060.0  4000.0  4020.0  3910.784912   88861700
# 2019-06-12  3880.0  3950.0  3840.0  3940.0  3940.000000  134724400
# 2019-06-13  3940.0  3990.0  3900.0  3990.0  3990.000000  115734700
# 2019-06-14  4020.0  4050.0  3970.0  3990.0  3990.000000   92466800
#
# [65 rows x 6 columns]

# %%
a = tm['2019-04']['Close']
# plt.plot(a.Close)
a
# Out:
# Date
# 2019-04-01    3930.0
# 2019-04-02    3930.0
# 2019-04-03    3930.0
# 2019-04-04    4030.0
# 2019-04-05    4060.0
# 2019-04-08    3950.0
# 2019-04-09    3950.0
# 2019-04-10    3930.0
# 2019-04-11    3890.0
# 2019-04-12    3830.0
# 2019-04-15    3830.0
# 2019-04-16    3870.0
# 2019-04-17    3870.0
# 2019-04-18    3860.0
# 2019-04-19    3860.0
# 2019-04-22    3780.0
# 2019-04-23    3850.0
# 2019-04-24    3840.0
# 2019-04-25    3830.0
# 2019-04-26    3910.0
# 2019-04-29    3860.0
# 2019-04-30    3790.0
# Name: Close, dtype: float64

# %% [markdown]
# # No.1

# %%
plt.figure(figsize=(12,5),dpi=300)
plt.plot(tm.Close, color='red')
plt.plot(isat.Close, color='blue')
plt.plot(fr.Close,color='lightblue')
plt.plot(xl.Close,color='green')
plt.xlabel("Tanggal")
plt.suptitle('Grafik Harga Saham Provider Telekomunikasi di Indonesia',
         fontdict={'family':'calibri', 'size':20, 'color':'black'},y = 1.1)
plt.xticks(rotation=45, size=6)
plt.ylabel("Rupiah IDR")
plt.legend(["PT Telekomunikasi Indonesia Tbk", "PT Indosat tbk", "PT Smartfren Telecom Tbk","PT XL Axiata Tbk"],
           bbox_to_anchor=(0., 1.02, 1., .102), loc='upper left', ncol = 4, mode="expand", borderaxespad=0.)

# %% [markdown]
# # No.2

# %%
a = tm['2019-04']['Close']
b = isat['2019-04']['Close'] 
c = xl['2019-04']['Close']
d = fr['2019-04']['Close']
plt.figure(figsize=(12,5),dpi=300)
plt.plot(a, color='red')
plt.plot(b, color='blue')
plt.plot(c,color='green')
plt.plot(d,color='lightblue')
plt.xlabel("Tanggal")
plt.suptitle('Grafik Harga Saham Provider Telekomunikasi di Indonesia(Juni 2019)',
         fontdict={'family':'calibri', 'size':30, 'color':'black'},y = 1.1)
plt.xticks(rotation=45, size=10)
plt.ylabel("Rupiah IDR")
plt.legend(["PT Telekomunikasi Indonesia Tbk", "PT Indosat tbk", "PT Smartfren Telecom Tbk","PT XL Axiata Tbk"],
           bbox_to_anchor=(0., 1.02, 1., .102), loc='upper left', ncol = 4, mode="expand", borderaxespad=0.)
