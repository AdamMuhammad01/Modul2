# %% [markdown]
# ___
#
# <a href='https://www.purwadhika.com/'> <img style="height: 200px" src='https://www.dicoding.com/images/original/event/201705181703334cc2c00c0d639e4593a12a55aa4c8103.png' /></a>
# ___
# # Seaborn Exercises - Solutions
#
# Time to practice your new seaborn skills! Try to recreate the plots below (don't worry about color schemes, just the plot itself.

# %% [markdown]
# ## The Data
#
# We will be working with a famous titanic data set for these exercises.

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
sns.set_style('whitegrid')

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic.iloc[1]
# Out:
# survived               1
# pclass                 1
# sex               female
# age                   38
# sibsp                  1
# parch                  0
# fare             71.2833
# embarked               C
# class              First
# who                woman
# adult_male         False
# deck                   C
# embark_town    Cherbourg
# alive                yes
# alone              False
# Name: 1, dtype: object

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.distplot(titanic['who'],bins=10,kde=False,color='g')
plt.ylabel('jumlah')
plt.xlabel('umur')
# Out:
# Text(0.5, 0, 'umur')

# %%
sns.distplot(titanic['fare'],bins=30,kde=False,color='red')

# %% [markdown]
# # Exercises
#
# ** Recreate the plots below using the titanic dataframe. There are very few hints since most of the plots can be done with just one or two lines of code and a hint would basically give away the solution. Keep careful attention to the x and y labels for hints.**
#
# ** *Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!* **

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# %%
plt.figure(figsize=(8,4),dpi=200)
sns.jointplot(x='fare',y='age',data=titanic)

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# %%
plt.figure(figsize=(8,4),dpi=200)
sns.distplot(titanic['fare'],bins=30,kde=False,color='red')

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# %%
sns.boxplot(x='class',y='age',data=titanic,palette='rainbow')

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# %%
sns.swarmplot(x='class',y='age',data=titanic,palette='Set2')
# Out:
# C:\Users\ADAM-PC\Anaconda\lib\site-packages\seaborn\categorical.py:1324: RuntimeWarning: invalid value encountered in less
#   off_low = points < low_gutter
# C:\Users\ADAM-PC\Anaconda\lib\site-packages\seaborn\categorical.py:1328: RuntimeWarning: invalid value encountered in greater
#   off_high = points > high_gutter

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# %%
sns.countplot(x='sex',data=titanic)

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# %%
plt.figure(figsize=(8,4),dpi=200)
sns.heatmap(titanic.corr(),cmap='coolwarm')
plt.title('titanic.corr()')
# Out:
# Text(0.5, 1, 'titanic.corr()')

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# %%
plt.figure(figsize=(10,4),dpi=200)
g = sns.FacetGrid(data=titanic,col='sex')
g.map(plt.hist,'age')

# %% [markdown]
# # Great Job!

# %%
ex = sns.load_dataset('exercise')
ex
# Out:
#     Unnamed: 0  id     diet  pulse    time     kind
# 0            0   1  low fat     85   1 min     rest
# 1            1   1  low fat     85  15 min     rest
# 2            2   1  low fat     88  30 min     rest
# 3            3   2  low fat     90   1 min     rest
# 4            4   2  low fat     92  15 min     rest
# ..         ...  ..      ...    ...     ...      ...
# 85          85  29   no fat    135  15 min  running
# 86          86  29   no fat    130  30 min  running
# 87          87  30   no fat     99   1 min  running
# 88          88  30   no fat    111  15 min  running
# 89          89  30   no fat    150  30 min  running
#
# [90 rows x 6 columns]

# %%
sns.stripplot(x="diet", y="pulse", data=ex, hue='kind')

# %%
sns.violinplot(x="diet", y="pulse", data=ex, hue='kind')

# %%
sns.swarmplot(x="diet", y="pulse", data=ex, hue='kind')

# %%
sns.boxplot(x="diet", y="pulse", data=ex, hue='kind')

# %%
sns.pointplot(x="diet", y="pulse", data=ex, hue='kind')

# %%
sns.barplot(x="diet", y="pulse", data=ex, hue='kind')

# %%
df_obj1 = pd.DataFrame({"x": np.random.randn(500),
                   "y": np.random.randn(500)})
 
df_obj2 = pd.DataFrame({"x": np.random.randn(500),
                   "y": np.random.randint(0, 100, 500)})

sns.jointplot(x="x", y="y", data=df_obj2)
sns.jointplot(x="x", y="y", data=df_obj2, kind="hex");
sns.jointplot(x="x", y="y", data=df_obj1, kind="kde");
dataset = sns.load_dataset("tips")
sns.pairplot(dataset);

# %%
# plt.figure(figsize=(8,4),dpi=200)
#titanic = sns.load_dataset('titanic')
planets = sns.load_dataset('planets')
#flights = sns.load_dataset('flights')
#iris = sns.load_dataset('iris')
planets = sns.load_dataset('planets')
# planets
sns.stripplot(x="year", y="distance", data=planets, hue='method')
# sns.swarmplot(x="diet", y="pulse", data=exercise, hue='kind')
# sns.boxplot(x="diet", y="pulse", data=exercise)
# sns.boxplot(x="diet", y="pulse", data=exercise, hue='kind')
# sns.violinplot(x="diet", y="pulse", data=exercise, hue='kind')
# sns.barplot(x="diet", y="pulse", data=exercise, hue='kind')
# sns.pointplot(x="diet", y="pulse", data=exercise, hue='kind');
plt.xticks(rotation=45, size=6)
plt.show()
